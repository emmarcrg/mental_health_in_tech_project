# %% [markdown]
# # La santé mentale dans le milieu de la tech

# %% [markdown]
# ## Récupération des données

# %% [markdown]
# ## Application des modèles
#
# Les modèles qui seront appliqués sont :
# - pour le **choix des features** : SHAP, un réseaux d'attention, des autoencodeurs
# - pour la **définition des probabilités** : une régression (type de régression à définir selon le modèle), un MLP, un FT-Transformer

# %% [markdown]
# ## Hyper-paramètrage

# %% [markdown]
# ## Comparaison des résultats obtenus
